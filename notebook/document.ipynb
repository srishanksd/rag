# %%
# !pip install langchain_core
# Out:
# Collecting langchain_core
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain_core)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain_core)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain_core)
#   Downloading langsmith-0.9.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\srish\AppData\Roaming\Python\Python311\site-packages (from langchain_core) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain_core) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_core)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\srish\AppData\Roaming\Python\Python311\site-packages (from langchain_core) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain_core)
#   Downloading uuid_utils-0.16.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading orjson-3.11.9-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)
# Collecting websockets>=15.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading websockets-16.0-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.15)
# Requirement already satisfied: h11>=0.16 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.7.0)
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/557.4 kB ? eta -:--:--
#    ---------------------------------------- 557.4/557.4 kB 2.1 MB/s  0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.9.3-py3-none-any.whl (619 kB)
#    ---------------------------------------- 0.0/619.9 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/619.9 kB ? eta -:--:--
#    ---------------------------------------- 619.9/619.9 kB 2.3 MB/s  0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.16.2-cp311-cp311-win_amd64.whl (176 kB)
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Downloading orjson-3.11.9-cp311-cp311-win_amd64.whl (127 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading websockets-16.0-cp311-cp311-win_amd64.whl (178 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, websockets, uuid-utils, tenacity, orjson, langchain-protocol, jsonpatch, requests-toolbelt, langsmith, langchain_core
#
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    ---- -----------------------------------  1/10 [websockets]
#    -------- -------------------------------  2/10 [uuid-utils]
#    ------------ ---------------------------  3/10 [tenacity]
#    ------------ ---------------------------  3/10 [tenacity]
#    ------------------------ ---------------  6/10 [jsonpatch]
#    ---------------------------- -----------  7/10 [requests-toolbelt]
#    ---------------------------- -----------  7/10 [requests-toolbelt]
#    ---------------------------- -----------  7/10 [requests-toolbelt]
#    ---------------------------- -----------  7/10 [requests-toolbelt]
#    ---------------------------- -----------  7/10 [requests-toolbelt]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    -------------------------------- -------  8/10 [langsmith]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ------------------------------------ ---  9/10 [langchain_core]
#    ---------------------------------------- 10/10 [langchain_core]
#
# Successfully installed jsonpatch-1.33 langchain-protocol-0.0.18 langchain_core-1.4.8 langsmith-0.9.3 orjson-3.11.9 requests-toolbelt-1.0.0 tenacity-9.1.4 uuid-utils-0.16.2 websockets-16.0 zstandard-0.25.0
# WARNING: Cache entry deserialization failed, entry ignored

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata = {
        "source":"example.txt",
        "pages":1,
        "author":"Srishank",
        "data_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Srishank', 'data_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
import os
os.makedirs("../data/text_files", exist_ok = True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt ":"""  
    Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,[38] an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.
    Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5,[39] capabilities and keywords for typing were added to the language, allowing optional static typing.[40] As of 2026, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the project's annual release cycle and five-year support policy. Python 3.15 is currently in the beta development phase, and the stable release is expected to launch in October 2026.[41] Earlier versions in the 3.x series have reached end-of-life and no longer receive security updates.
    Python has gained extensive use in the machine learning community.[42][43][44][45] It is widely taught as an introductory programming language.[46] Since 2003, Python has consistently ranked among the top ten most popular programming languages in the TIOBE Programming Community Index, which ranks programming languages based on searches across 24 platforms."""
}
for filepath, content in sample_texts.items():
    with open(filepath,'w', encoding='utf-8') as f:
        f.write(content)
        
print("Sample text files created")
# Out:
# Sample text files created

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.3.11-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain) (1.4.8)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Downloading langgraph-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.9.3)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\srish\AppData\Roaming\Python\Python311\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\srish\AppData\Roaming\Python\Python311\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.1.1)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.7.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.15)
# Requirement already satisfied: h11>=0.16 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\srish\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.7.0)
# Downloading langchain-1.3.11-py3-none-any.whl (133 kB)
# Downloading langgraph-1.2.6-py3-none-any.whl (246 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl (117 kB)
# Installing collected packages: websockets, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 16.0
#
#     Uninstalling websockets-16.0:
#
#       Successfully uninstalled websockets-16.0
#
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ----- ---------------------------------- 1/7 [ormsgpack]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------------- ---------------------- 3/7 [langgraph-checkpoint]
#    ----------------- ---------------------- 3/7 [langgraph-checkpoint]
#    ----------------- ---------------------- 3/7 [langgraph-checkpoint]
#    ---------------------- ----------------- 4/7 [langgraph-prebuilt]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------------- 7/7 [langchain]
#
# Successfully installed langchain-1.3.11 langgraph-1.2.6 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 ormsgpack-1.12.2 websockets-15.0.1

# %%
# !pip install langchain_community.document_loaders
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain_community.document_loaders (from versions: none)
# ERROR: No matching distribution found for langchain_community.document_loaders

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='  \n    Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,[38] an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.\nGuido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5,[39] capabilities and keywords for typing were added to the language, allowing optional static typing.[40] As of 2026, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the project\'s annual release cycle and five-year support policy. Python 3.15 is currently in the beta development phase, and the stable release is expected to launch in October 2026.[41] Earlier versions in the 3.x series have reached end-of-life and no longer receive security updates.\nPython has gained extensive use in the machine learning community.[42][43][44][45] It is widely taught as an introductory programming language.[46] Since 2003, Python has consistently ranked among the top ten most popular programming languages in the TIOBE Programming Community Index, which ranks programming languages based on searches across 24 platforms.')]

# %%
### Directory loader
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    '../data/text_files',
    glob = "**/*.txt",
    loader_cls = TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)
document = dir_loader.load()
document
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='  \n    Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,[38] an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.\nGuido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5,[39] capabilities and keywords for typing were added to the language, allowing optional static typing.[40] As of 2026, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the project\'s annual release cycle and five-year support policy. Python 3.15 is currently in the beta development phase, and the stable release is expected to launch in October 2026.[41] Earlier versions in the 3.x series have reached end-of-life and no longer receive security updates.\nPython has gained extensive use in the machine learning community.[42][43][44][45] It is widely taught as an introductory programming language.[46] Since 2003, Python has consistently ranked among the top ten most popular programming languages in the TIOBE Programming Community Index, which ranks programming languages based on searches across 24 platforms.')]

# %%
# Out:
# a  b
